# %% [markdown]
# # Chapter 2: Statistics and Probability Refresher, and Python Practice

# %% [markdown]
# <div id="toc"></div>

# %% [markdown]
# ## 2.1 Types of data

# %% [markdown]
# ### Numerical data

# %% [markdown]
# ### Categorical data

# %% [markdown]
# ### Ordinal data

# %% [markdown]
# ## 2.2 Mean, median, and mode
# ### Mean
# ### Median
# ### Mode

# %% [markdown]
# ## 2.3 Using mean, median, and mode in Python

# %% [markdown]
# ### Calculating mean using the NumPy package

# %% [markdown]
# ### Calculating median using the NumPy package

# %% [markdown]
# ### Calculating mode using the SciPy package

# %%
import numpy as np
incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# 26993.925402035879

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes, 50)
plt.show()

# %% [markdown]
# ## 2.4 Standard deviation and variance
# ### Variance
# ### Standard deviation
# ### Population variance versus sample variance
# ### Analyzing standard deviation and variance on a histogram
# ### Using Python to compute standard deviation and variance
# ### Try it yourself

# %% [markdown]
# ## 2.5 Probability density function and probability mass function

# %% [markdown]
# ### The probability density function and probability mass functions

# %% [markdown]
# ## 2.6 Types of data distributions

# %% [markdown]
# ###  Uniform distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
values = np.random.uniform(-10.0, 10.0, 100000)
plt.hist(values, 50)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
values = np.random.uniform(0, 1, 10000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# ### Normal or Gaussian distribution

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
x = np.arange(-3, 3, 0.001)
plt.plot(x, norm.pdf(x))

# %%
import numpy as np
import matplotlib.pyplot as plt
mu = 5.0
sigma = 2.0
values = np.random.normal(mu, sigma, 10000)
plt.hist(values, 50)
plt.show()

# %% [markdown]
# ### The exponential probability distribution or Power law

# %%
from scipy.stats import expon
import matplotlib.pyplot as plt
x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x))

# %% [markdown]
# ### Binomial probability mass function

# %%
from scipy.stats import expon
import matplotlib.pyplot as plt
x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x))

# %% [markdown]
# ### Poisson probability mass function

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
mu = 500
x = np.arange(400, 600, 0.5)
plt.plot(x, poisson.pmf(x, mu))

# %% [markdown]
# ## 2.7 Percentiles and moments

# %% [markdown]
# ### Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
vals = np.random.normal(0, 0.5, 10000)
plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# 0.0027117407440681741

# %%
np.percentile(vals, 90)
# Out:
# 0.6442219417148306

# %%
np.percentile(vals, 20)
# Out:
# -0.42153638933570647

# %% [markdown]
# ### Moments

# %%
import numpy as np
import matplotlib.pyplot as plt
vals = np.random.normal(0, 0.5, 10000)
plt.hist(vals, 50)
plt.show()

# %%
np.mean(vals)
# Out:
# 0.006048684614803383

# %%
np.var(vals)

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# -0.03694698446537649

# %%
sp.kurtosis(vals)
# Out:
# 0.05907974966935381

# %% [markdown]
# ## 2.8 Summary
